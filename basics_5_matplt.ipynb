# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./insurance.csv')
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
f = (df.loc[:, 'gender'] == 'female').sum()
m = df.loc[:, 'gender'].str.startswith('male').sum()
print(m, f)
# Out:
# 676 662

# %%
f = df.loc[:, 'gender'].str.contains('female')
f = df.loc[f, 'gender'].value_counts()[0]
m = df.loc[:, 'gender'].str.startswith('male')
m = df.loc[m, 'gender'].value_counts()[0]
print(m, f)
# Out:
# 676 662

# %%
# f = df.loc[:, 'gender'].str.contains('female')
# f=df.loc[f,'gender'].index
# m = df.loc[:, 'gender'].str.startswith('male')
# m = df.loc[m, 'gender'].index
# print(m,f)
# Out:
# Int64Index([   1,    2,    3,    4,    8,   10,   12,   14,   15,   17,
#             ...
#             1317, 1318, 1320, 1321, 1322, 1324, 1325, 1327, 1329, 1333],
#            dtype='int64', length=676) Int64Index([   0,    5,    6,    7,    9,   11,   13,   16,   20,   21,
#             ...
#             1323, 1326, 1328, 1330, 1331, 1332, 1334, 1335, 1336, 1337],
#            dtype='int64', length=662)

# %%
plt.bar([0.2, 2.5], [f, m])
# Out:
# <BarContainer object of 2 artists>

# %%
sm = ((df['gender'].str.startswith('male')) & (df['smoker'] == 'yes')).sum()
sf = ((df['gender'].str.startswith('female')) & (df['smoker'] == 'yes')).sum()

# %%
plt.bar([0.2, 1.4, 3.9, 5.1], [f, sf, m, sm])
# plt.ticklabel_format(['female'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.plot([m, f], [sm, sf])

# %%
# sw chile >2 male and female bar graph
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('./insurance.csv')
df

male = ((df['gender'].str.startswith('male')) & (df['children'] > 2)).sum()
female = ((df['gender'].str.startswith('female')) & (df['children'] > 2)).sum()
plt.bar([.5, 1.5], [male, female])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # 11/10/22

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
roll = [1, 2, 3, 4, 5, 6]
eng = [89, 54, 56, 56, 89, 78]
math = [34, 12, 56, 99, 56, 78]

plt.plot(roll, eng)

# %%
plt.plot(eng, roll)
plt.show()

# %%
plt.plot(roll, eng, color='Black')
plt.plot(roll, math)
plt.xlabel('roll no')
plt.ylabel('marks')
plt.legend(['english', 'maths'])
plt.title('roll numbers vs marks')
plt.text(2, 12, 'abc', fontsize=16, color='Blue')
plt.yticks([i for i in range(5, 101, 5)])
plt.show()

# %%
# scatter method

color = ['green', 'blue', 'black', 'purple', 'yellow', 'red']
plt.scatter(roll, eng, marker='^', color=color)
plt.scatter(roll, math, color=color)
# plt.scatter(roll,eng,marker='^',color='green')
plt.xlabel('roll no')
plt.ylabel('marks')
plt.legend(['english', 'maths'])
plt.title('roll numbers vs marks')
plt.show()

# %%
df = pd.read_csv('./insurance.csv')
df_original = df
df
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# females bmi(x),charges
# males bmi(x),charges
f = (df['gender'] == 'female')
m = (df['gender'].str.contains('male'))

df_bmi_f = df.loc[f, 'bmi']
df_ch_f = df.loc[f, 'charges']

df_bmi_m = df.loc[m, 'bmi']
df_ch_m = df.loc[m, 'charges']

plt.scatter(df_bmi_f, df_ch_f, marker='^')
plt.scatter(df_bmi_m, df_ch_m)
plt.xlabel('bmi')
plt.ylabel('charges')
plt.legend(['females', 'males'])

# %%
df = pd.read_csv('./Mall_Customers.csv')
# annual score and sending score
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
m = (df['Genre'].str.contains('Male'))
f = (df['Genre'].str.contains('Female'))

df_ss_f = df.loc[f, 'Spending Score (1-100)']
df_ai_f = df.loc[f, 'Annual Income (k$)']

df_ss_m = df.loc[m, 'Spending Score (1-100)']
df_ai_m = df.loc[m, 'Annual Income (k$)']

plt.scatter(df_ai_f, df_ss_f, marker='^')
plt.scatter(df_ai_m, df_ss_m)
plt.ylabel('Spending Score (1-100)')
plt.xlabel('Annual Income (k$)')
plt.legend(['females', 'males'])
plt.title(' annual income Spending score ')
# mid range diff color
# Out:
# Text(0.5, 1.0, ' annual income Spending score ')

# %% [markdown]
# # 13/10/22

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
arr = np.linspace(0, 15, 61)
arr
# Out:
# array([ 0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,  1.75,  2.  ,
#         2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,  4.  ,  4.25,
#         4.5 ,  4.75,  5.  ,  5.25,  5.5 ,  5.75,  6.  ,  6.25,  6.5 ,
#         6.75,  7.  ,  7.25,  7.5 ,  7.75,  8.  ,  8.25,  8.5 ,  8.75,
#         9.  ,  9.25,  9.5 ,  9.75, 10.  , 10.25, 10.5 , 10.75, 11.  ,
#        11.25, 11.5 , 11.75, 12.  , 12.25, 12.5 , 12.75, 13.  , 13.25,
#        13.5 , 13.75, 14.  , 14.25, 14.5 , 14.75, 15.  ])

# %%
x = np.linspace(0, 15, 60)
y = np.sin(x)
# plt.style.use('ggplot')
plt.style.use(['ggplot', 'tableau-colorblind10',
              'fast', 'seaborn-dark-palette'])
plt.plot(x, y)
print(plt.style.available)
plt.show()
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.plot(x, y, '--', lw=0.8)

# %%
# plt.plot(x,y,'o--',lw=0.8)
plt.plot(x, y, '--o', lw=0.8)

# %%
plt.plot(x, y, '^--', lw=0.8, color='green')

# %%
plt.plot(x, y, '^', lw=0.8, color='green')  # scatter
plt.xlabel('data1', color='blue', fontsize=14)
plt.ylabel('data2')
# Out:
# Text(0, 0.5, 'data2')

# %%
y1 = np.sin(x)*.2+np.random.randn(60)

# %%
plt.figure(figsize=(10, 2))
plt.plot(x, y, '--', lw=0.8)
plt.plot(x, y1, 'o', color='blue')
plt.legend(['D1', 'D2'], loc='upper left', ncol=2)

# %%
plt.figure(figsize=(10, 2))
plt.plot(x, y, '--', lw=0.8)
plt.plot(x, y1, 'o', color='blue')
plt.legend(['D1', 'D2'], loc='upper left', ncol=2)
y2 = abs(y-y1)
y2
# ind = (y2 > .25)
ind = np.where(y2 < .25)[0]
ind
y3 = y1[ind]
y3
x1 = x[ind]
plt.plot(x1, y3, 'o', color='orange')

# %%
df = pd.read_csv('./Mall_Customers.csv')
df_original = df
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
ss = df.loc[:, 'Spending Score (1-100)']
ai = df.loc[:, "Annual Income (k$)"]
ist = (df['Annual Income (k$)'] <= 50) & (df['Spending Score (1-100)'] >= 50)
istai = df.loc[ist, "Annual Income (k$)"]
istss = df.loc[ist, 'Spending Score (1-100)']

sec = (df['Annual Income (k$)'] <= 50) & (df['Spending Score (1-100)'] <= 50)
secai = df.loc[sec, "Annual Income (k$)"]
secss = df.loc[sec, 'Spending Score (1-100)']

thi = (df['Annual Income (k$)'] >= 60) & (df['Spending Score (1-100)'] >= 60)
thiai = df.loc[thi, "Annual Income (k$)"]
thiss = df.loc[thi, 'Spending Score (1-100)']

# four = (df['Annual Income (k$)'] >= 60) & (df['Spending Score (1-100)'] >= 60)
# thiai = df.loc[thi, "Annual Income (k$)"]
# thiss = df.loc[thi, 'Spending Score (1-100)']
#
#  fifth = (df['Annual Income (k$)'] >= 60) & (df['Spending Score (1-100)'] >= 60)
# thiai = df.loc[thi, "Annual Income (k$)"]
# thiss = df.loc[thi, 'Spending Score (1-100)']

plt.plot(istai, istss, 'o', color='blue')
plt.plot(secai, secss, 'o', color='red')
plt.plot(thiai, thiss, 'o', color='black')

# plt.plot(ai, ss, 'o')
# plt.style.use('ggplot')
plt.xlabel('anual income')
plt.ylabel('Spending Score')
# Out:
# Text(0, 0.5, 'Spending Score')

# %% [markdown]
# # 17/10/22

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
df=pd.read_csv('./Mall_Customers.csv')
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
an=df['Annual Income (k$)']
sp=df['Spending Score (1-100)']
ans=an.std()
sps=sp.std()
s='\n'.join((f'std_a={ans}',f'std_b={sps}'))
print(s)
plt.plot(an,sp,'^')
plt.text(100,60,s)
# Out:
# std_a=26.264721165271254
# std_b=25.823521668370162
# Text(100, 60, 'std_a=26.264721165271254\nstd_b=25.823521668370162')

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
arr = np.random.randn(1000)
arr1 = np.random.randn(1000)
plt.hist(arr, bins=30, color='orange', histtype='bar')
plt.hist(arr1, bins=30)
# Out:
# (array([ 4.,  6.,  3.,  6., 13., 24., 23., 30., 44., 38., 65., 83., 87.,
#         78., 68., 83., 67., 63., 52., 47., 37., 29., 19.,  8.,  9.,  5.,
#          3.,  2.,  2.,  2.]),
#  array([-2.80725457, -2.60832907, -2.40940357, -2.21047808, -2.01155258,
#         -1.81262708, -1.61370158, -1.41477608, -1.21585058, -1.01692508,
#         -0.81799958, -0.61907408, -0.42014858, -0.22122308, -0.02229758,
#          0.17662792,  0.37555342,  0.57447892,  0.77340442,  0.97232991,
#          1.17125541,  1.37018091,  1.56910641,  1.76803191,  1.96695741,
#          2.16588291,  2.36480841,  2.56373391,  2.76265941,  2.96158491,
#          3.16051041]),
#  <BarContainer object of 30 artists>)

# %%
arr2 = np.random.randn(1000)
x, y = np.histogram((arr, arr2), bins=30)
print(y, x)
plt.hist(arr, bins=30, histtype='step')
plt.hist(arr2, bins=30)
# Out:
# [-3.45123759 -3.22067755 -2.99011751 -2.75955747 -2.52899744 -2.2984374
#  -2.06787736 -1.83731732 -1.60675728 -1.37619725 -1.14563721 -0.91507717
#  -0.68451713 -0.4539571  -0.22339706  0.00716298  0.23772302  0.46828305
#   0.69884309  0.92940313  1.15996317  1.3905232   1.62108324  1.85164328
#   2.08220332  2.31276335  2.54332339  2.77388343  3.00444347  3.2350035
#   3.46556354] [  1   0   2   6  15  18  24  36  63  84 104 133 171 170 187 177 163 167
#  133 112  72  66  33  31  15   7   5   3   1   1]
# (array([ 1.,  2.,  5.,  7.,  9., 12., 12., 31., 28., 37., 51., 74., 79.,
#         73., 78., 69., 75., 64., 57., 56., 48., 39., 29., 26., 13., 11.,
#          4.,  2.,  6.,  2.]),
#  array([-2.91209429, -2.7217875 , -2.5314807 , -2.3411739 , -2.15086711,
#         -1.96056031, -1.77025351, -1.57994672, -1.38963992, -1.19933312,
#         -1.00902633, -0.81871953, -0.62841273, -0.43810594, -0.24779914,
#         -0.05749234,  0.13281445,  0.32312125,  0.51342805,  0.70373484,
# ...

# %%
plt.hist(arr, cumulative=True)
# Out:
# (array([   2.,   24.,   83.,  239.,  490.,  758.,  916.,  981.,  996.,
#         1000.]),
#  array([-3.45123759, -2.75955747, -2.06787736, -1.37619725, -0.68451713,
#          0.00716298,  0.69884309,  1.3905232 ,  2.08220332,  2.77388343,
#          3.46556354]),
#  <BarContainer object of 10 artists>)

# %%
# pie chart
lst = [10, 12, 11, 9, 5]
dev = ['Python', 'c++', 'c', 'java', 'Go']
# plt.pie(lst,labels=dev,colors=['red','green','blue','violet','purple'],labeldistance=0.5)
plt.pie(lst, labels=dev, colors=['red', 'green',
        'blue', 'violet', 'purple'], labeldistance=1.3)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f55210f3610>,
# ...
#  [Text(1.0202391896275982, 0.8056748698749526, 'Python'),
#   Text(-0.6995070874890195, 1.0957599347268676, 'c++'),
#   Text(-1.1185220332420491, -0.6625016687919152, 'c'),
#   Text(0.38515832688010465, -1.2416332241185069, 'java'),
#   Text(1.2280698560425907, -0.42643220877359933, 'Go')])

# %%
# voilin plot
# a=[12,14,1,4,5,8]
#
# lables
#

a = np.array([12, 14, 1, 4, 4, 5, 8])
b = [50, 4, 5, 3, 5, 7, 8, 9]
# plt.violinplot(a,showmeans=True,showmedians=True) mean median label
pos = [1, 2]
plt.violinplot([a, b], pos, bw_method='silverman',showextrema=True,showmeans=True,showmedians=True)
plt.text(0.8,a.mean(),'mean')
plt.legend(['arr1','arr2'])
# plt.violinplot(b)

# %%
arr1 = np.random.randn(1000)
arr2 = np.sin(arr1)
plt.plot(arr1, arr2,'p')
plt.grid(linestyle='--')

# %% [markdown]
# # 18/10/22

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv('./Data.csv')
df
# Out:
#      Place   age   Income Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# machine learnining steps
# 1. Data cleaning
# 2. Data Visualization
# 3. Encoding
# 4. Feature scaling
# 5. Divide data into training and testing
# 6. Model building
# 7. Model Testing
# 8. if efficiency is not good then go to step 1 or change training technique
